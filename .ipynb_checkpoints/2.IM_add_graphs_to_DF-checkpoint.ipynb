# %% [markdown]
# # Create text graphs
# * This notebook takes the newsela/britannica folder and the newsela/britannica.csv file and:
#     1. Annotates the files (output: csv/newselaORbritannica_with_annotation.csv)
#     2. Removes outliers on a test set by the Sematch package.
#     3. Breaks the nodes into sentences and paragraphs.
#     4. Creates the text graphs as described in Stajner and Hulpus (2015).
#
# * The final output of running this specific notebook is csv/britannica_with_graphs.csv
# * Can be run with different data sets - newsela/britannica_semrel/britannica_sematch_with_graphs.csv were created with this notebook

# %% [markdown]
# #### Import requirements

# %%
from ast import literal_eval
import codecs
from collections import defaultdict
import itertools
import networkx as nx
import nltk
nltk.download('wordnet')
nltk.download('wordnet_ic')
from nltk import word_tokenize
import numpy as np
import pandas as pd
import requests
from sematch.semantic.similarity import EntitySimilarity #changed the semantic/sparql.py file 
                                                         #to be compatible with python 3
import spacy
import spotlight
import time
from tqdm import tqdm, tqdm_notebook
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package wordnet to /home/edit/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet_ic to /home/edit/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!

# %% [markdown]
# #### Define helper functions

# %%
def load_data(file_name):
    '''
    function that loads CSV files
    without adding new column for index
    '''
    df = pd.read_csv(file_name, index_col=0)
    return df

# %%
def annotate_text(text):
    '''
    function that takes a string as argument and returns a dictionary 
    as desribed in https://pypi.org/project/pyspotlight/
    confidence value is set based on experiment and literature described in the paper
    the "URI" values of the dictionary are used for further experiments
    '''
    try:
        annotation = spotlight.annotate(
            "https://api.dbpedia-spotlight.org/en/annotate",
            str(text),
            confidence=0.35,
            support=20,
        )
        return annotation
    
    #added to control for missing annotation when the link throws an error 
    except:
        return [0]

# %%
def annotate_df(series_of_file_paths):
    '''
    function that takes the series of file paths as seen in the newsela.csv
    and returns a list of annotations that can be added to the DF
    '''
    list_of_annotations = []
    for path in tqdm(series_of_file_paths):    
        with codecs.open(path.replace("IM/", ""), "r", encoding="utf-8", errors="ignore") as f:
            text_annotations = []
            text = f.read()
            text_annotation = annotate_text(str(text))
            list_of_annotations.append(text_annotation)

    return list_of_annotations

# %%
def create_graph(annotation, max_path_length=4):
    '''
    function that creates a graph based on an annotation dictionary created by the annotate_text() function    
    part 1 of the graph creation as described by Stajner and Hulpus (2015)
    forms a graph of all nodes connected to the original nodes up to the max_path_length
    using DBPedia JSON files under "http://dbpedia.org/data/"
    returns a networkx Graph object
    max path length parameter is set to 4 as in the paper 
    
    '''    
    start = time.time()
    
    old_annotation = []
    
    graph = nx.Graph()
    for layer in range(max_path_length-1): 
        for node in annotation:
            if node not in old_annotation:
                if ("resource" in node and node[7:9] == "db" and "Category" not in node
                   and "List" not in node):#
                    #check dpbedia entries only, 'category' and 'list' give meaningless results
                    try:
                        data = requests.get("http://dbpedia.org/data/" + node[27:] + ".json").json()
                        item = data[node]
                        keys = [key for key in item if item[key][0]["type"] == "uri"]
                        for key in keys:

                            if ("resource" in item[key][0]["value"]
                                and item[key][0]["value"][7:9] == "db"
                            ):  
                                if (key != "http://www.w3.org/2002/07/owl#sameAs"):  #####exclude non-english entries
                                    graph.add_edge(node, item[key][0]["value"], prop=key)
                    except:
                        #print(node) ###### can be used to control which nodes are not found
                        pass

        old_annotation = annotation
        annotation = set(graph.nodes())
       
    end = time.time()
    #print("Time taken:", end - start)  ######## can be used to control timing
    return graph

# %%
def select_related_nodes(graph, annotation):
    '''
    part 2 of the graph creation as described by Stajner and Hulpus (2015)
    only keep nodes that are related to the original nodes present in the text by path lenths up to 4
    returns networkx Graph objects
    needs an annotation as returned by the annotate_text() function
    '''   
    limited_text_graph = nx.Graph().to_undirected()
    nx_graph = graph.to_undirected()
    #print("Undirected networkx graph created.") # was used to check timing

    for node in annotation:
        limited_text_graph.add_node(node)
    
    annotation_pairs = list(itertools.combinations(annotation, 2))
    for pair in (set(annotation_pairs)): #tqdm_notebook was used earlier to check timing

        if pair[0] in nx_graph.nodes() and pair[1] in nx_graph.nodes():
            paths = list(nx.simple_paths.all_simple_paths(nx_graph, (pair[0]), (pair[1]), 4))
            if paths != []:

                for path in paths:
                    for related_nodes in list(zip(path, path[1:])):
                        
                        limited_text_graph.add_edge(
                            related_nodes[0],
                            related_nodes[1],
                            prop=graph.get_edge_data(
                                related_nodes[0], related_nodes[1])["prop"],)
    
    #these were not part of the graph so far
    isolates = list(nx.isolates(limited_text_graph))
    
    return limited_text_graph, isolates

# %%
nlp = spacy.load("en_core_web_sm")

def return_nodes_per_sent(path, anno):
    '''
    based on the columns 'path' and 'annotation' from the DF
    returns a list of lists, where each sublist contains nodes from one sentence
    used to average the feature values per sentence
    '''
    with codecs.open(path.replace("IM/",""), "r", encoding='utf-8', errors='ignore') as f:
        
        all_nodes=[]
        text = f.read()
        doc = nlp(text)
        sentences = list(doc.sents)
        for sent in sentences:
            
            sentence_nodes = set()

            for word in sent:
                for dic in literal_eval(anno):
                    if str(word) == dic["surfaceForm"]:
                        sentence_nodes.add(dic["URI"])
            
            all_nodes.append(sentence_nodes)
            
    return all_nodes

# %%
def return_nodes_per_para(path, anno):
    '''
    based on the columns 'path' and 'annotation' from the DF
    returns a list of lists, where each sublist contains nodes from one paragraph
    used to average the feature values per paragraph
    '''
    with codecs.open(path.replace("IM/",""), "r", encoding='utf-8', errors='ignore') as f:
        
        all_nodes=[]
        text = f.read()
        
        paragraphs = text.split('\n')

        for para in paragraphs:
            
            para_nodes = set()

            for word in word_tokenize(para):
                for dic in literal_eval(anno):
                    if str(word) == dic["surfaceForm"]:
                        para_nodes.add(dic["URI"])
            
            all_nodes.append(para_nodes)
            
    return all_nodes

# %% [markdown]
# #### Load and annotate data

# %%
def load_and_annotate_df(df_path, folder='britannica/'):
    df = load_data(df_path)
    df["annotations"] = str
    df["annotations"] = annotate_df(folder+df["path"])
    return df

# %%
df = load_and_annotate_df('csv/britannica.csv')
df.head()
# Out:
# 100%|██████████| 117/117 [03:28<00:00,  1.78s/it]
#                        path             name     score  level  \
# 0      african_penguin_kids  african-penguin      kids      2
# 1  african_penguin_scholars  african-penguin  scholars      0
# 2  african_penguin_students  african-penguin  students      1
# 3           bald_eagle_kids       bald-eagle      kids      2
# 4       bald_eagle_scholars       bald-eagle  scholars      0
#
#                                          annotations
# 0  [{'URI': 'http://dbpedia.org/resource/African_...
# 1  [{'URI': 'http://dbpedia.org/resource/African_...
# 2  [{'URI': 'http://dbpedia.org/resource/African_...
# 3  [{'URI': 'http://dbpedia.org/resource/Bald_eag...
# 4  [{'URI': 'http://dbpedia.org/resource/Bald_eag...

# %%
#test if there are any empty annotations
for ind,row in df.iterrows():
    if df['annotations'][ind] == [0]:
        print(ind)

# %%
#if needed, this function can annotate the missing texts, based on the index from previous cell
def annotate_missing_text(ind, folder='newsela/'):
    file_name = df["path"][ind]
    with open(folder+file_name) as f:
        file = f.read()
    df['annotations'][ind] = annotate_text(file)

# %%
#annotate_missing_text(977)

# %%
#save DF
df.to_csv('csv/britannica_with_annotations.csv')

# %% [markdown]
# <hr style="rgb(0,0,0);height: 15.0px;"/>

# %% [markdown]
# #### Outlier removal with Sematch

# %%
df = load_data('csv/britannica_with_annotations.csv')

# %%
sim = EntitySimilarity()

# %%
def remove_outliers(annotation, threshold=0.2): ##########0.2 based on manual testing
    
    relatedness=defaultdict(list)
    cleaned_annotations = []
    
    for pair in tqdm(list(itertools.combinations([dic["URI"] for dic in literal_eval(annotation)], 2))):
        rel = (sim.relatedness(pair[0],pair[1]))
        
        relatedness[pair[0]].append(rel)
        relatedness[pair[1]].append(rel)
                     
    for key in relatedness:
        relatedness[key]=np.mean(relatedness[key])
        if relatedness[key] > threshold:
            cleaned_annotations.append(key)  
            
    return relatedness, cleaned_annotations

# %% [markdown]
# * Testing for threshold value - two examples from Newsela data

# %%
test = remove_outliers(df["annotations"][0])
# Out:
# 100%|██████████| 1485/1485 [25:19<00:00,  1.04it/s]

# %%
test[0]
# Out:
# defaultdict(list,
#             {'http://dbpedia.org/resource/Police_dog': 0.5090655987614584,
#              'http://dbpedia.org/resource/Texas': 0.6880030870285047,
#              'http://dbpedia.org/resource/Brittany': 0.38944078906160096,
#              'http://dbpedia.org/resource/Golden_Retriever': 0.40973838803481033,
#              'http://dbpedia.org/resource/Dog': 0.5503373487867458,
#              'http://dbpedia.org/resource/New_York_City': 0.8153091972845675,
#              'http://dbpedia.org/resource/Sleep': 0.2990742300267429,
#              'http://dbpedia.org/resource/Firefighter': 0.507604486291097,
#              'http://dbpedia.org/resource/Flag_of_the_United_States': 0.5323630461139134,
#              'http://dbpedia.org/resource/Volunteer_fire_department': 0.2323340662724604,
#              'http://dbpedia.org/resource/Family': 0.7492827212252995,
#              'http://dbpedia.org/resource/Fixed-wing_aircraft': 0.5302183387945506,
#              'http://dbpedia.org/resource/Hotel': 0.723246576045306,
#              'http://dbpedia.org/resource/Denise_Fox': 0.13900775845142657,
#              'http://dbpedia.org/resource/Corliss_steam_engine': 0.1394951656932243,
#              'http://dbpedia.org/resource/Puppy': 0.392460104391622,
#              'http://dbpedia.org/resource/Train': 0.6607154793442034,
#              'http://dbpedia.org/resource/Police': 0.6632384290733471,
#              'http://dbpedia.org/resource/September_11_attacks': 0.694464937474136,
#              'http://dbpedia.org/resource/George_H._W._Bush': 0.8063671382263821,
#              'http://dbpedia.org/resource/United_States': 0.9157985032159756})

# %%
df["annotations"][0]
# Out:
# [{'URI': 'http://dbpedia.org/resource/Police_dog',
#   'support': 510,
#   'types': '',
#   'surfaceForm': 'K9',
#   'offset': 0,
#   'similarityScore': 0.9999995822221044,
#   'percentageOfSecondRank': 4.177780900825528e-07},
#  {'URI': 'http://dbpedia.org/resource/Texas',
#   'support': 136284,
#   'types': 'Wikidata:Q3455524,Schema:Place,Schema:AdministrativeArea,DBpedia:Region,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:AdministrativeRegion',
#   'surfaceForm': 'Texas',
#   'offset': 85,
#   'similarityScore': 0.999981639340906,
#   'percentageOfSecondRank': 6.308142280775235e-06},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 93,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Golden_Retriever',
#   'support': 407,
#   'types': '',
#   'surfaceForm': 'golden retriever',
#   'offset': 108,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Dog',
#   'support': 12528,
#   'types': '',
#   'surfaceForm': 'dog',
#   'offset': 130,
#   'similarityScore': 0.999999988997388,
#   'percentageOfSecondRank': 1.1002490485333078e-08},
#  {'URI': 'http://dbpedia.org/resource/New_York_City',
#   'support': 190508,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'New York City',
#   'offset': 209,
#   'similarityScore': 0.999999996173301,
#   'percentageOfSecondRank': 3.72855182003111e-09},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 224,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Sleep',
#   'support': 5345,
#   'types': '',
#   'surfaceForm': 'sleep',
#   'offset': 244,
#   'similarityScore': 0.8879928146106213,
#   'percentageOfSecondRank': 0.1214641339171897},
#  {'URI': 'http://dbpedia.org/resource/Firefighter',
#   'support': 2290,
#   'types': '',
#   'surfaceForm': 'firefighters',
#   'offset': 330,
#   'similarityScore': 0.9783817997224632,
#   'percentageOfSecondRank': 0.02209534090464791},
#  {'URI': 'http://dbpedia.org/resource/Dog',
#   'support': 12528,
#   'types': '',
#   'surfaceForm': 'dog',
#   'offset': 381,
#   'similarityScore': 0.999999988997388,
#   'percentageOfSecondRank': 1.1002490485333078e-08},
#  {'URI': 'http://dbpedia.org/resource/Firefighter',
#   'support': 2290,
#   'types': '',
#   'surfaceForm': 'firefighters',
#   'offset': 445,
#   'similarityScore': 0.9783817997224632,
#   'percentageOfSecondRank': 0.02209534090464791},
#  {'URI': 'http://dbpedia.org/resource/Flag_of_the_United_States',
#   'support': 2195,
#   'types': '',
#   'surfaceForm': 'American flag',
#   'offset': 481,
#   'similarityScore': 0.9999999982212557,
#   'percentageOfSecondRank': 1.7788334862051495e-09},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 496,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/New_York_City',
#   'support': 190508,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'New York City',
#   'offset': 597,
#   'similarityScore': 0.999999996173301,
#   'percentageOfSecondRank': 3.72855182003111e-09},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 612,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Dog',
#   'support': 12528,
#   'types': '',
#   'surfaceForm': 'dog',
#   'offset': 693,
#   'similarityScore': 0.999999988997388,
#   'percentageOfSecondRank': 1.1002490485333078e-08},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 739,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Volunteer_fire_department',
#   'support': 490,
#   'types': '',
#   'surfaceForm': 'volunteer',
#   'offset': 801,
#   'similarityScore': 0.9979484374779555,
#   'percentageOfSecondRank': 0.0020557800654109827},
#  {'URI': 'http://dbpedia.org/resource/Firefighter',
#   'support': 2290,
#   'types': '',
#   'surfaceForm': 'firefighters',
#   'offset': 858,
#   'similarityScore': 0.9783817997224632,
#   'percentageOfSecondRank': 0.02209534090464791},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 876,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Family',
#   'support': 5995,
#   'types': '',
#   'surfaceForm': 'family',
#   'offset': 914,
#   'similarityScore': 0.9759574006327564,
#   'percentageOfSecondRank': 0.024473856708570003},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 963,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1037,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/New_York_City',
#   'support': 190508,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'New York City',
#   'offset': 1054,
#   'similarityScore': 0.999999996173301,
#   'percentageOfSecondRank': 3.72855182003111e-09},
#  {'URI': 'http://dbpedia.org/resource/Fixed-wing_aircraft',
#   'support': 1461,
#   'types': '',
#   'surfaceForm': 'airplane',
#   'offset': 1074,
#   'similarityScore': 0.7405006361533872,
#   'percentageOfSecondRank': 0.35043751918720895},
#  {'URI': 'http://dbpedia.org/resource/Hotel',
#   'support': 12430,
#   'types': '',
#   'surfaceForm': 'hotel',
#   'offset': 1105,
#   'similarityScore': 0.999888382883525,
#   'percentageOfSecondRank': 5.614748639140086e-05},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1145,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Denise_Fox',
#   'support': 325,
#   'types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q95074,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:SoapCharacter,DBpedia:Person,DBpedia:FictionalCharacter,DBpedia:Agent',
#   'surfaceForm': 'Denise',
#   'offset': 1171,
#   'similarityScore': 0.6057928969193872,
#   'percentageOfSecondRank': 0.6507288622424572},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1178,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1187,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1199,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Puppy',
#   'support': 345,
#   'types': '',
#   'surfaceForm': 'puppy',
#   'offset': 1225,
#   'similarityScore': 0.9904741331249126,
#   'percentageOfSecondRank': 0.009617481724963127},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1232,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Train',
#   'support': 8219,
#   'types': '',
#   'surfaceForm': 'train',
#   'offset': 1255,
#   'similarityScore': 0.9998782408533324,
#   'percentageOfSecondRank': 7.54011111041115e-05},
#  {'URI': 'http://dbpedia.org/resource/Police',
#   'support': 16833,
#   'types': '',
#   'surfaceForm': 'police',
#   'offset': 1278,
#   'similarityScore': 0.9971457734405986,
#   'percentageOfSecondRank': 0.0022782747795290553},
#  {'URI': 'http://dbpedia.org/resource/Firefighter',
#   'support': 2290,
#   'types': '',
#   'surfaceForm': 'firefighters',
#   'offset': 1289,
#   'similarityScore': 0.9783817997224632,
#   'percentageOfSecondRank': 0.02209534090464791},
#  {'URI': 'http://dbpedia.org/resource/Texas',
#   'support': 136284,
#   'types': 'Wikidata:Q3455524,Schema:Place,Schema:AdministrativeArea,DBpedia:Region,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:AdministrativeRegion',
#   'surfaceForm': 'Texas',
#   'offset': 1400,
#   'similarityScore': 0.999981639340906,
#   'percentageOfSecondRank': 6.308142280775235e-06},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1463,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Dog',
#   'support': 12528,
#   'types': '',
#   'surfaceForm': 'dog',
#   'offset': 1486,
#   'similarityScore': 0.999999988997388,
#   'percentageOfSecondRank': 1.1002490485333078e-08},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1605,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1618,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/New_York_City',
#   'support': 190508,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'New York City',
#   'offset': 1644,
#   'similarityScore': 0.999999996173301,
#   'percentageOfSecondRank': 3.72855182003111e-09},
#  {'URI': 'http://dbpedia.org/resource/September_11_attacks',
#   'support': 15402,
#   'types': '',
#   'surfaceForm': 'Sept. 11, 2001',
#   'offset': 1680,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1748,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Firefighter',
#   'support': 2290,
#   'types': '',
#   'surfaceForm': 'firefighter',
#   'offset': 1776,
#   'similarityScore': 0.9999999606282025,
#   'percentageOfSecondRank': 3.9371839437299144e-08},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1819,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1832,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1873,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 1940,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 1954,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 2007,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/George_H._W._Bush',
#   'support': 6344,
#   'types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Person,DBpedia:OfficeHolder,DBpedia:Agent',
#   'surfaceForm': 'Bush',
#   'offset': 2044,
#   'similarityScore': 0.6611346247803163,
#   'percentageOfSecondRank': 0.5125511815742939},
#  {'URI': 'http://dbpedia.org/resource/United_States',
#   'support': 563995,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'United States',
#   'offset': 2091,
#   'similarityScore': 0.9999942927205732,
#   'percentageOfSecondRank': 4.9967009075135586e-06},
#  {'URI': 'http://dbpedia.org/resource/Corliss_steam_engine',
#   'support': 135,
#   'types': '',
#   'surfaceForm': 'Corliss',
#   'offset': 2106,
#   'similarityScore': 0.9943451704571089,
#   'percentageOfSecondRank': 0.005653856984513597},
#  {'URI': 'http://dbpedia.org/resource/Brittany',
#   'support': 7640,
#   'types': 'Wikidata:Q486972,Schema:Place,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location',
#   'surfaceForm': 'Bretagne',
#   'offset': 2151,
#   'similarityScore': 0.9613999954526835,
#   'percentageOfSecondRank': 0.04014978584314553}]

# %%
test2 = remove_outliers(df["annotations"][6])
# Out:
# 100%|██████████| 2775/2775 [1:04:40<00:00,  1.32s/it]

# %%
test2[0]
# Out:
# defaultdict(list,
#             {'http://dbpedia.org/resource/Food': 0.5074505976921527,
#              'http://dbpedia.org/resource/Afghanistan': 0.6520561037556565,
#              'http://dbpedia.org/resource/Financial_capital': 0.3119354629114519,
#              'http://dbpedia.org/resource/Kabul': 0.4792197772871563,
#              'http://dbpedia.org/resource/Hot_dog': 0.435428258362215,
#              'http://dbpedia.org/resource/North_America': 0.744968895363626,
#              'http://dbpedia.org/resource/Navid': 0.15236097892942538,
#              'http://dbpedia.org/resource/Toronto': 0.7730697869700689,
#              'http://dbpedia.org/resource/Canada': 0.870624684127026,
#              'http://dbpedia.org/resource/Abdullah_of_Saudi_Arabia': 0.49199216822151287,
#              'http://dbpedia.org/resource/Hamburger': 0.455370212231134,
#              'http://dbpedia.org/resource/Chicken_as_food': 0.3614870481368901,
#              'http://dbpedia.org/resource/Mustard_seed': 0.4079663070170393,
#              'http://dbpedia.org/resource/Truck': 0.5478927375229844,
#              'http://dbpedia.org/resource/WWE_Network': 0.4755223192008676,
#              'http://dbpedia.org/resource/Truck_driver': 0.4617222031885934,
#              'http://dbpedia.org/resource/Types_of_tennis_match': 0.03337497651301487,
#              'http://dbpedia.org/resource/Hairnet': 0.2542435568340836,
#              'http://dbpedia.org/resource/Plastic': 0.5495167266409592,
#              'http://dbpedia.org/resource/Grilling': 0.3615715155368265,
#              'http://dbpedia.org/resource/Smoke': 0.41134166609097766,
#              'http://dbpedia.org/resource/French_fries': 0.4493808457710089,
#              'http://dbpedia.org/resource/Afghan_cuisine': 0.26788813200581885,
#              'http://dbpedia.org/resource/Paper': 0.5818015184515914,
#              'http://dbpedia.org/resource/Litter': 0.42222322398957624,
#              'http://dbpedia.org/resource/Medicine': 0.6698817839210974,
#              'http://dbpedia.org/resource/Idris_of_Libya': 0.4221486739119395,
#              'http://dbpedia.org/resource/Horse_tack': 0.3168171852573455,
#              'http://dbpedia.org/resource/Sandwich': 0.42710988209935774,
#              'http://dbpedia.org/resource/Food_truck': 0.3496046447354612,
#              'http://dbpedia.org/resource/Family': 0.7625913108268552,
#              'http://dbpedia.org/resource/Pakistan': 0.7207961483570194,
#              'http://dbpedia.org/resource/Three-wheeler': 0.34595800231970697,
#              'http://dbpedia.org/resource/Ketchup': 0.349248959869104,
#              'http://dbpedia.org/resource/Patty': 0.3678591257276792,
#              "http://dbpedia.org/resource/Vladimir_Zhirinovsky's_donkey_video": 0.14762231832950468,
#              'http://dbpedia.org/resource/David_Dhawan': 0.328411501759737,
#              'http://dbpedia.org/resource/Police': 0.5881027448553658,
#              'http://dbpedia.org/resource/Hassle_Records': 0.09352407574314127})

# %%
df["annotations"][6]
# Out:
# [{'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 19,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 62,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Financial_capital',
#   'support': 1291,
#   'types': '',
#   'surfaceForm': 'capital',
#   'offset': 74,
#   'similarityScore': 0.6093330899527369,
#   'percentageOfSecondRank': 0.6410369074282207},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 85,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 191,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'Hot dogs',
#   'offset': 205,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 233,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dogs',
#   'offset': 313,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Financial_capital',
#   'support': 1291,
#   'types': '',
#   'surfaceForm': 'capital',
#   'offset': 354,
#   'similarityScore': 0.6093330899527369,
#   'percentageOfSecondRank': 0.6410369074282207},
#  {'URI': 'http://dbpedia.org/resource/North_America',
#   'support': 39216,
#   'types': 'Schema:Place,Schema:Continent,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Continent',
#   'surfaceForm': 'North America',
#   'offset': 411,
#   'similarityScore': 0.854434516931656,
#   'percentageOfSecondRank': 0.17036470340805787},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 456,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 486,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Navid',
#   'support': 35,
#   'types': '',
#   'surfaceForm': 'Naveed',
#   'offset': 513,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 1.2352696330440831e-14},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 542,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Toronto',
#   'support': 81638,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Toronto',
#   'offset': 583,
#   'similarityScore': 0.9999999999772626,
#   'percentageOfSecondRank': 7.755724226852643e-12},
#  {'URI': 'http://dbpedia.org/resource/Canada',
#   'support': 220739,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Canada',
#   'offset': 592,
#   'similarityScore': 0.9999998991511398,
#   'percentageOfSecondRank': 1.006889604565279e-07},
#  {'URI': 'http://dbpedia.org/resource/Toronto',
#   'support': 81638,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Toronto',
#   'offset': 609,
#   'similarityScore': 0.9999999999772626,
#   'percentageOfSecondRank': 7.755724226852643e-12},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 642,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 686,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Abdullah_of_Saudi_Arabia',
#   'support': 1112,
#   'types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Royalty,DBpedia:Person,DBpedia:Agent',
#   'surfaceForm': 'Abdullah',
#   'offset': 729,
#   'similarityScore': 0.6014377176870256,
#   'percentageOfSecondRank': 0.5892434176922785},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dogs',
#   'offset': 825,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Hamburger',
#   'support': 1226,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'burgers',
#   'offset': 835,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 9.58953205261281e-15},
#  {'URI': 'http://dbpedia.org/resource/Chicken_as_food',
#   'support': 2550,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'chicken',
#   'offset': 847,
#   'similarityScore': 0.9999974822057858,
#   'percentageOfSecondRank': 2.489953120103189e-06},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 1055,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Mustard_seed',
#   'support': 298,
#   'types': '',
#   'surfaceForm': 'mustard',
#   'offset': 1183,
#   'similarityScore': 0.9930107918019895,
#   'percentageOfSecondRank': 0.007038378989672516},
#  {'URI': 'http://dbpedia.org/resource/Truck',
#   'support': 4187,
#   'types': '',
#   'surfaceForm': 'truck',
#   'offset': 1292,
#   'similarityScore': 0.9999991617973012,
#   'percentageOfSecondRank': 6.725312404932642e-07},
#  {'URI': 'http://dbpedia.org/resource/WWE_Network',
#   'support': 652,
#   'types': 'Wikidata:Q43229,Wikidata:Q24229398,Wikidata:Q15265344,DUL:SocialPerson,DUL:Agent,Schema:TelevisionStation,Schema:Organization,DBpedia:TelevisionStation,DBpedia:Organisation,DBpedia:Broadcaster,DBpedia:Agent',
#   'surfaceForm': 'swerved',
#   'offset': 1356,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Truck_driver',
#   'support': 561,
#   'types': '',
#   'surfaceForm': 'truck driver',
#   'offset': 1387,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Types_of_tennis_match',
#   'support': 2158,
#   'types': '',
#   'surfaceForm': 'doubles',
#   'offset': 1405,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 5.1948333244171425e-15},
#  {'URI': 'http://dbpedia.org/resource/Hairnet',
#   'support': 31,
#   'types': '',
#   'surfaceForm': 'hair net',
#   'offset': 1435,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Plastic',
#   'support': 5214,
#   'types': '',
#   'surfaceForm': 'plastic',
#   'offset': 1448,
#   'similarityScore': 0.9990361733757881,
#   'percentageOfSecondRank': 0.0009647564720618492},
#  {'URI': 'http://dbpedia.org/resource/Grilling',
#   'support': 603,
#   'types': '',
#   'surfaceForm': 'grilling',
#   'offset': 1471,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 7.588821061199981e-17},
#  {'URI': 'http://dbpedia.org/resource/Hamburger',
#   'support': 1226,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'burgers',
#   'offset': 1480,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 9.58953205261281e-15},
#  {'URI': 'http://dbpedia.org/resource/Smoke',
#   'support': 1306,
#   'types': '',
#   'surfaceForm': 'Smoke',
#   'offset': 1489,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 2.829456697387075e-14},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dogs',
#   'offset': 1605,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/French_fries',
#   'support': 1064,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'fries',
#   'offset': 1633,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 7.409322004899647e-44},
#  {'URI': 'http://dbpedia.org/resource/Afghan_cuisine',
#   'support': 79,
#   'types': '',
#   'surfaceForm': 'Afghani',
#   'offset': 1675,
#   'similarityScore': 0.999974997068133,
#   'percentageOfSecondRank': 2.5002304145500552e-05},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 1717,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 1799,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Paper',
#   'support': 6829,
#   'types': '',
#   'surfaceForm': 'paper',
#   'offset': 1820,
#   'similarityScore': 0.9999953172205599,
#   'percentageOfSecondRank': 4.682786264296945e-06},
#  {'URI': 'http://dbpedia.org/resource/Truck',
#   'support': 4187,
#   'types': '',
#   'surfaceForm': 'truck',
#   'offset': 1900,
#   'similarityScore': 0.9999991617973012,
#   'percentageOfSecondRank': 6.725312404932642e-07},
#  {'URI': 'http://dbpedia.org/resource/Litter',
#   'support': 364,
#   'types': '',
#   'surfaceForm': 'littering',
#   'offset': 1920,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Truck',
#   'support': 4187,
#   'types': '',
#   'surfaceForm': 'truck',
#   'offset': 1960,
#   'similarityScore': 0.9999991617973012,
#   'percentageOfSecondRank': 6.725312404932642e-07},
#  {'URI': 'http://dbpedia.org/resource/Medicine',
#   'support': 15923,
#   'types': '',
#   'surfaceForm': 'medical students',
#   'offset': 1999,
#   'similarityScore': 0.8800565860011164,
#   'percentageOfSecondRank': 0.1362905702961192},
#  {'URI': 'http://dbpedia.org/resource/Idris_of_Libya',
#   'support': 322,
#   'types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Royalty,DBpedia:Person,DBpedia:Agent',
#   'surfaceForm': 'Mohammed Idris',
#   'offset': 2037,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Chicken_as_food',
#   'support': 2550,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'chicken',
#   'offset': 2116,
#   'similarityScore': 0.9999974822057858,
#   'percentageOfSecondRank': 2.489953120103189e-06},
#  {'URI': 'http://dbpedia.org/resource/Horse_tack',
#   'support': 286,
#   'types': '',
#   'surfaceForm': 'bit',
#   'offset': 2178,
#   'similarityScore': 0.9999964071385845,
#   'percentageOfSecondRank': 3.2000584032896375e-06},
#  {'URI': 'http://dbpedia.org/resource/Sandwich',
#   'support': 1861,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'sandwich',
#   'offset': 2195,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 3.020463447809732e-26},
#  {'URI': 'http://dbpedia.org/resource/Food_truck',
#   'support': 324,
#   'types': '',
#   'surfaceForm': 'food truck',
#   'offset': 2283,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'Hot dogs',
#   'offset': 2300,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 2331,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Afghan_cuisine',
#   'support': 79,
#   'types': '',
#   'surfaceForm': 'Afghani',
#   'offset': 2395,
#   'similarityScore': 0.999974997068133,
#   'percentageOfSecondRank': 2.5002304145500552e-05},
#  {'URI': 'http://dbpedia.org/resource/Afghan_cuisine',
#   'support': 79,
#   'types': '',
#   'surfaceForm': 'Afghani',
#   'offset': 2466,
#   'similarityScore': 0.999974997068133,
#   'percentageOfSecondRank': 2.5002304145500552e-05},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 2474,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dog',
#   'offset': 2524,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 1.6507128685102195e-24},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dog',
#   'offset': 2537,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 1.6507128685102195e-24},
#  {'URI': 'http://dbpedia.org/resource/Family',
#   'support': 5995,
#   'types': '',
#   'surfaceForm': 'family',
#   'offset': 2571,
#   'similarityScore': 0.9999907453603427,
#   'percentageOfSecondRank': 5.767391922614022e-06},
#  {'URI': 'http://dbpedia.org/resource/Afghanistan',
#   'support': 48460,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Afghanistan',
#   'offset': 2586,
#   'similarityScore': 0.9999989505746321,
#   'percentageOfSecondRank': 1.0485084921499918e-06},
#  {'URI': 'http://dbpedia.org/resource/Pakistan',
#   'support': 103240,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Pakistan',
#   'offset': 2637,
#   'similarityScore': 0.9999999796846171,
#   'percentageOfSecondRank': 1.289799744316798e-08},
#  {'URI': 'http://dbpedia.org/resource/Kabul',
#   'support': 8993,
#   'types': 'Wikidata:Q515,Wikidata:Q486972,Schema:Place,Schema:City,DBpedia:Settlement,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:City',
#   'surfaceForm': 'Kabul',
#   'offset': 2666,
#   'similarityScore': 0.9999999999022293,
#   'percentageOfSecondRank': 9.783139345834062e-11},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dogs',
#   'offset': 2779,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Three-wheeler',
#   'support': 160,
#   'types': '',
#   'surfaceForm': 'three-wheeled',
#   'offset': 2812,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Ketchup',
#   'support': 785,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'ketchup',
#   'offset': 3003,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 7.043721257553242e-46},
#  {'URI': 'http://dbpedia.org/resource/Chicken_as_food',
#   'support': 2550,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'chicken',
#   'offset': 3016,
#   'similarityScore': 0.9999974822057858,
#   'percentageOfSecondRank': 2.489953120103189e-06},
#  {'URI': 'http://dbpedia.org/resource/Hot_dog',
#   'support': 1202,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'hot dogs',
#   'offset': 3024,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Pakistan',
#   'support': 103240,
#   'types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   'surfaceForm': 'Pakistan',
#   'offset': 3065,
#   'similarityScore': 0.9999999796846171,
#   'percentageOfSecondRank': 1.289799744316798e-08},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 3091,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/Chicken_as_food',
#   'support': 2550,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'chicken',
#   'offset': 3168,
#   'similarityScore': 0.9999974822057858,
#   'percentageOfSecondRank': 2.489953120103189e-06},
#  {'URI': 'http://dbpedia.org/resource/Patty',
#   'support': 151,
#   'types': '',
#   'surfaceForm': 'patties',
#   'offset': 3176,
#   'similarityScore': 1.0,
#   'percentageOfSecondRank': 0.0},
#  {'URI': "http://dbpedia.org/resource/Vladimir_Zhirinovsky's_donkey_video",
#   'support': 21,
#   'types': '',
#   'surfaceForm': 'video ad',
#   'offset': 3321,
#   'similarityScore': 0.9999989686189882,
#   'percentageOfSecondRank': 0.0},
#  {'URI': 'http://dbpedia.org/resource/Food',
#   'support': 9216,
#   'types': '',
#   'surfaceForm': 'food',
#   'offset': 3376,
#   'similarityScore': 0.9883228701429909,
#   'percentageOfSecondRank': 0.011812835279352781},
#  {'URI': 'http://dbpedia.org/resource/David_Dhawan',
#   'support': 179,
#   'types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Person,DBpedia:Agent',
#   'surfaceForm': 'Rohit',
#   'offset': 3450,
#   'similarityScore': 0.999999999577085,
#   'percentageOfSecondRank': 4.229117599635688e-10},
#  {'URI': 'http://dbpedia.org/resource/Chicken_as_food',
#   'support': 2550,
#   'types': 'Wikidata:Q2095,DUL:FunctionalSubstance,DBpedia:Food',
#   'surfaceForm': 'chicken',
#   'offset': 3541,
#   'similarityScore': 0.9999974822057858,
#   'percentageOfSecondRank': 2.489953120103189e-06},
#  {'URI': 'http://dbpedia.org/resource/Police',
#   'support': 16833,
#   'types': '',
#   'surfaceForm': 'police',
#   'offset': 3629,
#   'similarityScore': 0.9999999909096005,
#   'percentageOfSecondRank': 8.628251720627079e-09},
#  {'URI': 'http://dbpedia.org/resource/Hassle_Records',
#   'support': 25,
#   'types': 'Wikidata:Q43229,Wikidata:Q24229398,Wikidata:Q18127,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:RecordLabel,DBpedia:Organisation,DBpedia:Company,DBpedia:Agent',
#   'surfaceForm': 'hassle',
#   'offset': 3649,
#   'similarityScore': 0.9999994047190692,
#   'percentageOfSecondRank': 5.73274452957871e-07}]

# %% [markdown]
# * Testing for graphs - examples from Britannica

# %%
df_test = df[:45]
df_test['clean_anno']=str
for ind,row in df_test.iterrows():
    try:
        df_test['clean_anno'][ind]=remove_outliers(df['annotations'][ind])
    except:
        print(ind)

# %%
df_test.to_csv('csv/britannica_sematch.csv')

# %% [markdown]
# <hr style="rgb(0,0,0);height: 20.0px;"/>

# %% [markdown]
# #### Add nodes per sentences and paragraph to DF

# %%
#if used for outlier removal, has to be 'clean_anno' instead of 'annotations'
def add_nodes_per_sent(df, name, folder='britannica/'):
    df["sentences"] = str
    for ind, anno in df.iterrows():
        df["sentences"][ind] = return_nodes_per_sent(folder+df['path'][ind],df['annotations'][ind])
    return df

# %%
df = add_nodes_per_sent(df, 'britannica','')
df.head()
# Out:
#                             path       name     score  level  \
# 0      britannica/albatross_kids  albatross      kids      2
# 1  britannica/albatross_scholars  albatross  scholars      0
# 2  britannica/albatross_students  albatross  students      1
# 3         britannica/canary_kids     canary      kids      2
# 4     britannica/canary_scholars     canary  scholars      0
#
#                                          annotations  \
# 0  [{'URI': 'http://dbpedia.org/resource/Flying_a...
# 1  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 2  [{'URI': 'http://dbpedia.org/resource/Gliding'...
# 3  [{'URI': 'http://dbpedia.org/resource/Domestic...
# 4  [{'URI': 'http://dbpedia.org/resource/Serinus'...
#
#                                            sentences  \
# 0  [{}, {}, {}, {}, {}, {}, {http://dbpedia.org/r...
# 1  [{http://dbpedia.org/resource/Family, http://d...
# 2  [{http://dbpedia.org/resource/Albatross}, {htt...
# 3  [{http://dbpedia.org/resource/Domestic_canary,...
# 4  [{http://dbpedia.org/resource/Serinus, http://...
#
#                                           paragraphs  graph  \
# 0  [{'http://dbpedia.org/resource/Flying_and_glid...    NaN
# 1  [{'http://dbpedia.org/resource/Dutch_language'...    NaN
# 2  [{'http://dbpedia.org/resource/Poetry', 'http:...    NaN
# 3  [{'http://dbpedia.org/resource/Atlantic_canary...    NaN
# 4  [{'http://dbpedia.org/resource/Finch', 'http:/...    NaN
#
#                                            sel_graph  \
# 0  [('http://dbpedia.org/resource/Species', 'http...
# 1  [('http://dbpedia.org/resource/Albatross', 'ht...
# 2  [('http://dbpedia.org/resource/Albatross', 'ht...
# 3  [('http://dbpedia.org/resource/Domestic_canary...
# 4  [('http://dbpedia.org/resource/Serinus', 'http...
#
#                                             isolates  \
# 0  ['http://dbpedia.org/resource/Flying_and_glidi...
# 1  ['http://dbpedia.org/resource/Flying_and_glidi...
# 2  ['http://dbpedia.org/resource/Gliding', 'http:...
# 3  ['http://dbpedia.org/resource/Coast', 'http://...
# 4  ['http://dbpedia.org/resource/Species', 'http:...
#
#                                       sel_graph_data  \
# 0  [('http://dbpedia.org/resource/Species', 'http...
# 1  [('http://dbpedia.org/resource/Albatross', 'ht...
# 2  [('http://dbpedia.org/resource/Albatross', 'ht...
# 3  [('http://dbpedia.org/resource/Domestic_canary...
# 4  [('http://dbpedia.org/resource/Serinus', 'http...
#
#                                         cleaned_anno  \
# 0  ['http://dbpedia.org/resource/Species', 'http:...
# 1  ['http://dbpedia.org/resource/Albatross', 'htt...
# 2  ['http://dbpedia.org/resource/Albatross', 'htt...
# 3  ['http://dbpedia.org/resource/Domestic_canary'...
# 4  ['http://dbpedia.org/resource/Serinus', 'http:...
#
#                                        cleaned_anno_
# 0  [{'URI': 'http://dbpedia.org/resource/Species'...
# 1  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 2  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 3  [{'URI': 'http://dbpedia.org/resource/Domestic...
# 4  [{'URI': 'http://dbpedia.org/resource/Serinus'...

# %%
def add_nodes_per_para(df, name, folder='britannica/'):
    df["paragraphs"] = str
    for ind, anno in df.iterrows():
        df["paragraphs"][ind] = return_nodes_per_para(folder+df['path'][ind], (df["cleaned_anno_"][ind]))
    #df.to_csv('csv/' + name + '_with_paragraphs.csv')
    return df

# %%
df = add_nodes_per_para(df, 'britannica', '')
df.head()
# Out:
#                             path       name     score  level  \
# 0      britannica/albatross_kids  albatross      kids      2
# 1  britannica/albatross_scholars  albatross  scholars      0
# 2  britannica/albatross_students  albatross  students      1
# 3         britannica/canary_kids     canary      kids      2
# 4     britannica/canary_scholars     canary  scholars      0
#
#                                          annotations  \
# 0  [{'URI': 'http://dbpedia.org/resource/Flying_a...
# 1  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 2  [{'URI': 'http://dbpedia.org/resource/Gliding'...
# 3  [{'URI': 'http://dbpedia.org/resource/Domestic...
# 4  [{'URI': 'http://dbpedia.org/resource/Serinus'...
#
#                                            sentences  \
# 0  [{}, {}, {}, {}, {}, {}, {http://dbpedia.org/r...
# 1  [{http://dbpedia.org/resource/Family, http://d...
# 2  [{http://dbpedia.org/resource/Albatross}, {htt...
# 3  [{http://dbpedia.org/resource/Domestic_canary,...
# 4  [{http://dbpedia.org/resource/Serinus, http://...
#
#                                           paragraphs  graph  \
# 0  [{}, {}, {http://dbpedia.org/resource/Family, ...    NaN
# 1  [{http://dbpedia.org/resource/Mollymawk, http:...    NaN
# 2  [{http://dbpedia.org/resource/Syllable, http:/...    NaN
# 3  [{http://dbpedia.org/resource/Bird, http://dbp...    NaN
# 4  [{http://dbpedia.org/resource/Serinus, http://...    NaN
#
#                                            sel_graph  \
# 0  [('http://dbpedia.org/resource/Species', 'http...
# 1  [('http://dbpedia.org/resource/Albatross', 'ht...
# 2  [('http://dbpedia.org/resource/Albatross', 'ht...
# 3  [('http://dbpedia.org/resource/Domestic_canary...
# 4  [('http://dbpedia.org/resource/Serinus', 'http...
#
#                                             isolates  \
# 0  ['http://dbpedia.org/resource/Flying_and_glidi...
# 1  ['http://dbpedia.org/resource/Flying_and_glidi...
# 2  ['http://dbpedia.org/resource/Gliding', 'http:...
# 3  ['http://dbpedia.org/resource/Coast', 'http://...
# 4  ['http://dbpedia.org/resource/Species', 'http:...
#
#                                       sel_graph_data  \
# 0  [('http://dbpedia.org/resource/Species', 'http...
# 1  [('http://dbpedia.org/resource/Albatross', 'ht...
# 2  [('http://dbpedia.org/resource/Albatross', 'ht...
# 3  [('http://dbpedia.org/resource/Domestic_canary...
# 4  [('http://dbpedia.org/resource/Serinus', 'http...
#
#                                         cleaned_anno  \
# 0  ['http://dbpedia.org/resource/Species', 'http:...
# 1  ['http://dbpedia.org/resource/Albatross', 'htt...
# 2  ['http://dbpedia.org/resource/Albatross', 'htt...
# 3  ['http://dbpedia.org/resource/Domestic_canary'...
# 4  ['http://dbpedia.org/resource/Serinus', 'http:...
#
#                                        cleaned_anno_
# 0  [{'URI': 'http://dbpedia.org/resource/Species'...
# 1  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 2  [{'URI': 'http://dbpedia.org/resource/Albatros...
# 3  [{'URI': 'http://dbpedia.org/resource/Domestic...
# 4  [{'URI': 'http://dbpedia.org/resource/Serinus'...

# %%
#save df with sentences and paragraphs
df.to_csv('csv/britannica_with_units.csv')

# %% [markdown]
# <hr style="rgb(0,0,0);height: 20.0px;"/>

# %% [markdown]
# #### Add text graphs to DF

# %%
df = load_data('csv/britannica_with_units.csv')

# %%
def add_text_graphs_to_df(df, name):
    #initiate columns
    df["graph"] = str
    df["sel_graph"] = str
    df["isolates"] = str
    #save properties as well
    df["sel_graph_data"] = str
    
    for ind, anno in df[220:240].iterrows():
        df["graph"][ind] = create_graph([dic["URI"] for dic in literal_eval(df["annotations"][ind])])
        df["sel_graph"][ind] = select_related_nodes(df['graph'][ind],
                                                        [dic["URI"] for dic in literal_eval(df["annotations"][ind])])[0].edges()
        df['isolates'][ind]=select_related_nodes(df['graph'][ind],
                                                        [dic["URI"] for dic in literal_eval(df["annotations"][ind])])[1]
        
        df["sel_graph_data"][ind] = df["sel_graph"][ind].data()

        if ind % 2 == 0:
            df.to_csv('csv/'+name+'_with_graphs.csv')
            print("DF processed up to index ", ind)
        
    df.to_csv('csv/'+name+'_with_graphs.csv')
    return df

# %%
add_text_graphs_to_df(df, 'britannica')
